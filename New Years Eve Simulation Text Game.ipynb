# %%
#Name: Abdul Bishar
#Date: 10/09/2019


"""
    DocString:
    
    A) Introduction:
    This game is a simulation for a New Years Eve party...the simulation takes you through some typical expeirences 
    you might experience at a party. So grab a drink and get started!
    
    The game has 4 major scenes:
    
    1) Dancefloor
    2) Truth or dare game
    3) New years countdown
    4) Fight
    
    B) Known Bugs and/or Errors:
    
    1) Line 177: Couldn't wrap player_name in f"{player_name}" if I try this then python skips to end of game at line 346"
    2) Line 228 and 344: exit(0) not working...python just runs end of game at line 346
    3) If you start fight sequence with Block...your health will go over 100 
    
    
"""
# Out:
# '\n    DocString:\n    \n    A) Introduction:\n    This game is a simulation for a New Years Eve party...the simulation takes you through some typical expeirences \n    you might experience at a party. So grab a drink and get started!\n    \n    The game has 4 major scenes:\n    \n    1) Dancefloor\n    2) Truth or dare game\n    3) New years countdown\n    4) Fight\n    \n    B) Known Bugs and/or Errors:\n    \n    1) Line 177: Couldn\'t wrap player_name in f"{player_name}" if I try this then python skips to end of game at line 346"\n    2) Line 344: exit(0) not working...python just runs end of game at line 346\n    3) If you start fight sequence with Block...your health will go over 100 \n    \n    \n'

# %% [markdown]
# <img src ="2020newyearseve.jpg" style = "width:658px;height:306px"/>
#
#                            Welcome to New years eve SF (WARNING: You must be 21 years old or above to play)

# %%
import time
import winsound
import random
from IPython.display import Audio,Image
from sys import exit


global player_name

#Must be older than 21 to enter game
def age_verification():
    while True:
        try:
            age = int(input ("Please enter your age:\n"))
            years_left = int(21 - age)
            if age < 21 :
                 print (f"Looks like you are too young for this game... come back in {years_left} years!")
                    
#Stopping user from entering ridiculous age       
            elif age >= 100:
                time.sleep(2)
                print (f"""If you really were {age} years old then you\'ve been to enough new years parties and dont need to play this game
                       but we all know you\'re not {age} so how about we try that again""")
                age_verification()
            elif age>= 21:
                input("<Awesome! Press ENTER to get dressed up and head to the party!>\n")
                game_start()
 #stopping user from entering anything other than integer              
        except:
            time.sleep(2)
            print(" Look\'s like we got off on the wrong foot already...")
            time.sleep(2)
            print ("Try entering your age as an integer this time")
            age_verification()
    return age

    game_start()
    
#Welcoming to the party and collecting name
def game_start(): 
    print ("Erica: Hey you're here! I'm Erica... You're Jenny's friend right? Welcome to the party! ")
    time.sleep(3)
    print("Erica: Sorry for asking but what was your name again?")
    time.sleep(2)
    player_name = input("Tell Erica your name: \n")
    if player_name == "c3po" or player_name =="C3PO" or player_name == "r2d2" or player_name == "R2D2":
        print ("Hahaha")
        time.sleep (3)
        print("You found my first easter egg")
        time.sleep(3)
        print (f"Nice try, but i was just making a joke before...your mom and dad did not name you {player_name}")
        time.sleep (4)
        print (f"Besides if you really are {player_name}... why dont\'t you just code your own game!")
        time.sleep (4)
        print("let\'s try that again")
        time.sleep (2)
        game_start()

#Stopping player from entering alpha numeric name 
    elif not player_name.isalpha():
        time.sleep(2)
        print ("Come on...Unless you\'re name is C3PO or R2D2, i\'m pretty sure youre name doesn\'t have a number in it ")
        time.sleep (2)
        print ("So...let\'s try that again")
        time.sleep(2)
        game_start()
       
    else:
        time.sleep(2)
        print (f"Erica: Oh that\'s right!  {player_name}! Sorry i\'m bad with names..." )
        time.sleep(2)
        print (f"Erica: Well everone\'s here, come on inside {player_name}! The dancefloor is to the right")
        time.sleep(3)

        input('<Press ENTER to head to the dancefloor continue>\n')

        print('DJ: Hey can you do me a favor? I need to go to the bathroom real quick...here is my phone. You can pick the next song...')
        time.sleep (3)
        dancefloor()
    
#choice of music
def dancefloor():  
    print (""""
               What kind of music do you want to play?
               1) Country music
               2) Hip hop music
               3) EDM music
               4) Rock music
               """)
    choice = input(">  \n")
    choice = choice.casefold()
    
#Controlling for user inputs  
    if choice == "1"  or choice == "country"  or choice == "country music" or choice == "countrymusic":
        time.sleep (2)
        print("*** Country music is playing and everyone's doing the line dance! ***")
    elif choice == "2" or choice ==  "hip hop" or choice ==  "hip hop music" or choice ==  "hiphop music":
        time.sleep (2)
        print("*** Hip Hop music is playing and everyone's doing the dougie! ***")
    elif choice == "3" or choice ==  "edm" or choice ==  "edm music" or choice == "house" or choice == "electronic dance music":
        time.sleep (2)
        print("*** EDM music is playing and everyone's raving to the beat! ***")
    elif choice == "4" or choice == "rock" or choice == "rock music":
        time.sleep (2)
        print("*** Rock music is playing and you ended up starting a moshpit! ***")

    else:
        print ("Sorry i didn't get you, try entering the number of your choice")
        dancefloor()
    time.sleep(3)
    print ("Nice! Everyone loves the music choice! But now you noticed your friend Jenny who invited you...she's at the bar in the kitchen")
    
    
    input('<Press any key to head to the bar to continue>\n')
    
    bar()
    
def bar():
    print("Jenny: Hey you made it! Here have a drink ")
    time.sleep (3)
    print("Jenny: We're playing truth or dare and guess what...")
    time.sleep (3)
    print ("Jenny: It\'s YOUR turn!")
    time.sleep(3)
 
    truthordare()
    
def truthordare():
#truth or dare library:  
    dares = ["I dare you to do 30 push ups","I dare you to take a shot of tequila", " I dare you to go around the room and smell everyone's armpits","I dare you to give Abdul an A... my easter egg ;)"]
    truths = ["What\'s your new years resolution?","Tell us your biggest secret","Do you have a crush on Jenny","What are you most self concious about","When was the most imappropriate time you farted",]
    dareoutput = random.choice(dares)
    truthoutput = random.choice(truths)

    
    truth_or_dare = input("What do you choose? TRUTH or DARE?:\n")
    truth_or_dare = truth_or_dare.casefold()
    if truth_or_dare == "truth":
        print(f"{truthoutput}")
        truth = input()
        time.sleep(2)
        print ("Jenny: Seriously?, wow...i'm going to post that on Facebook right now.")
        time.sleep(3)
        print ("Jenny: Just kidding!")
        time.sleep (3)
        ask_again()
        
    elif truth_or_dare == "dare":
        print (f"{dareoutput}")
        time.sleep(5)
        print ("Wow, i can't believe you did that!")
        time.sleep(2)
        ask_again()
    else:
        time.sleep (3)
        print("Are you drunk already?")
        time.sleep(3)
        print ("Since nobody understood what you said, you killed the mood...nobody wants to talk to you anymore...and now you have to leave. Goodbye!")
        time.sleep (3)
        input("<press enter to try that part again>\n")
        truthordare()
        
#Asking if they want to play another round of truth or dare        
def ask_again():
    time.sleep(2)
    print("Jenny: Would you like to play again? (Yes/No)")
    replay = input("> ")
    replay = replay.casefold()

    if replay == 'yes':
        truthordare()


    elif replay == "no":
        time.sleep(2)
        print("{player_name}: No thanks!")
        countdown()
        
#Controlling for unexpected entry        
    else:
        time.sleep (2)
        print ("Jenny: What?....")
        time.sleep (2)
        print("I just asked you a yes or no question")
        time.sleep(2)
        ask_again()
        
#Going outside for new years countdown    
def countdown():
    time.sleep(2)
    print("Jenny: Well it's almost midnight...time to head outside and watch the fireworks!")
    time.sleep (2)
    input("< Press ENTER to head outside and watch the fireworks!>\n")
    time.sleep (2)
    print ("Jenny: Time for the countdown!")
    time.sleep (2)
    count = 10 
    while count > 0:
        print (count)
        count -=1
        
        input ("< Press ENTER to continue .>\n")
        
    print("Happy New Year!")
    fight()

#deciding fight or flight 
def fight():
    time.sleep (3)
    print ("People are starting to get drunk...")
    time.sleep (3)
    print("Someone bumps into you and spills their drink all over you and starts getting agressive..")
    time.sleep (4)
    print ("Stranger: Hey what's your problem!")
    time.sleep (3)
    print("***PUSHES YOU***")
    time.sleep(3)
    choice_1 = input ("Are you gonna push them back? No? Yes? or Hell yes?:\n")
    choice_1 = choice_1.casefold()

    if choice_1 == "no":
        print ("Stranger: That's what i thought! Go home!")
        time.sleep(2)
        print(f"{player_name}: Hey Jenny, the party was fun while it lasted but i think i'm going to leave...")
        time.sleep(3)
        print ("Jenny: Okay sorry about that, have a good night and happy new years! ")
        exit(0)
        

    elif choice_1 == "yes" or choice_1 == "hell yes":
        actual_fight()
        
    else:
        time.sleep(3)
        print ("Come on! This guy is about to swing at you!")
        time.sleep(3)
        print ("You gotta make a better decision!")
        time.sleep (3)
        print ("Let\'s try this again...'")
        time.sleep (2)
        print ("P.S. I would choose yes or hell yes")
        time.sleep (2)
        fight()

#The actual fight mechanics and sequence...Note that blocking gives some health (due to recovery)
def actual_fight():
    moves = {"jab": range(28, 36),
         "uppercut": range(30, 46),
         "block": range(10, 15)}

    class Character:
        def __init__(self, health):
            self.health = health

        def attack(self, other):
            raise NotImplementedError


    class Player(Character):
        """ You start with 100 health and have the choice of three moves """
        def __init__(self, health=100):
            super().__init__(health)

        def attack(self, other):
            while True:
                time.sleep(3)
                choice = str.lower(input("\nWhat move would you like to make? (Jab, Uppercut, or Block)"))

                if choice == "block":
                    self.health += int(random.choice(moves[choice]))
                    print("\nYour health is now {0.health}.".format(self))
                    break
                if choice == "jab" or choice == "uppercut":
                    damage = int(random.choice(moves[choice]))
                    other.health -= damage
                    print("\nYou attack with {0}, dealing {1} damage.".format(choice, damage))
                    break
                else:
                    print("Not a valid move, try again!")


    class Stranger(Character):
        """ The stranger, also starts with 100 health and chooses moves at random """
        def __init__(self, health=100):
            super().__init__(health)

        def attack(self, other):
            if self.health <= 35:
                moves_1 = ["jab", "uppercut", "block", "block", "block", "block", "block"]
                stranger_choice = random.choice(moves_1)
            else:
                stranger_choice = random.choice(list(moves))
            if stranger_choice == "jab" or stranger_choice == "uppercut":
                damage = int(random.choice(moves[stranger_choice]))
                other.health -= damage
                print("\nThe stranger attacks with {0}, dealing {1} damage.".format(stranger_choice, damage))
            if stranger_choice == "block":
                self.health += int(random.choice(moves[stranger_choice]))
                print("\nThe stranger uses block and his health is now {0.health}.".format(self))


    def battle(player, stranger):
        time.sleep(2)
        print("Stranger: Oh so you want to fight huh? LET'S GO!...")
        while player.health > 0 and stranger.health > 0:
            player.attack(stranger)
            if stranger.health <= 0:
                break
            print("\nThe strangers health is now {0.health}.".format(stranger))
            stranger.attack(player)
            if player.health <= 0:
                break
            print("\nYour health is now {0.health}.".format(player))
        # outcome
        if player.health > 0:
            print("You kicked that guys a**!")
            time.sleep (3)
            print("Wow...well this party escelated quickly...bet you weren't expecting that! I think now\'s a good time to head home")
            time.sleep(3)
            print ("Jenny: Wow...I didn't know you could fight...anyway, tonights been crazy...we should leave")
            time.sleep(3)
            input ("< Press ENTER to leave the party .>\n")
            fail()

        if stranger.health > 0:
            print("That stranger kicked your a**!")
            print ("Jenny: Oh my god are you okay? I think we should get out of here")
            input ("< Press ENTER to leave the party...you should probably go to the hospital .>\n")
            fail()
    if __name__ == '__main__':
            battle(Player(), Stranger())

            
def fail():
    print(f" Would you like to play again? (Yes/No)")
    replaygame = input("> ")
    replaygame = replaygame.casefold()
    
    if replaygame == 'yes':
        game_start()
        
    else:
        print(f"Thanks for playing!")
        exit(0)
    
age_verification()
# Out:
# Please enter your age:
# 26
# <Awesome! Press ENTER to get dressed up and head to the party!>
#
# Erica: Hey you're here! I'm Erica... You're Jenny's friend right? Welcome to the party!
# Erica: Sorry for asking but what was your name again?
# Tell Erica your name:
# jp
# Erica: Oh that's right!  jp! Sorry i'm bad with names...
# Erica: Well everone's here, come on inside jp! The dancefloor is to the right
# <Press ENTER to head to the dancefloor continue>
#
# DJ: Hey can you do me a favor? I need to go to the bathroom real quick...here is my phone. You can pick the next song...
# "
#                What kind of music do you want to play?
#                1) Country music
#                2) Hip hop music
#                3) EDM music
#                4) Rock music
#
# >
# 1
# *** Country music is playing and everyone's doing the line dance! ***
# Nice! Everyone loves the music choice! But now you noticed your friend Jenny who invited you...she's at the bar in the kitchen
# ...
